# %% [markdown]
# <a href="https://colab.research.google.com/github/Mai-Fakhry/Optical-character-recognition-OCR-/blob/main/OCR_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kaggle

# %%
# !ls /content
# Out:
# kaggle.json  sample_data

# %%
# !mkdir -p ~/.kaggle
# !cp /content/kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# Download and unzip
# !kaggle datasets download -d harieh/ocr-dataset --unzip
# Out:
# Dataset URL: https://www.kaggle.com/datasets/harieh/ocr-dataset
# License(s): CC0-1.0
# ...
#  81% 124M/153M [00:00<00:00, 1.30GB/s]
# 100% 153M/153M [00:00<00:00, 738MB/s]
